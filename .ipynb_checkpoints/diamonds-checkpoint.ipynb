# %% [markdown]
# # Seaborn 'diamonds' data seti üzerinde çalışma

# %% [markdown]
# * **diamonds** <br>
# _Belirli bazı elmaslar alınıp özelliklerinin veri seti_
#     * carat: Elmas ağırlığı (0.2-5.01 gram)
#     * cut: Elmasın kesim kalitesi (Fair, Good, Very Good, Premium, Ideal)
#     * color: Elmasın rengi (J en kötüsü, D en iyisi)
#     * clarity: Elmasın berraklığı (I1 (En kötü), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (En iyi))
#     * depth: Toplam derinlik yüzdesi (z/ortalama(x, y) = 2 * z / (x + y) (43-79))
#     * table: Elmasın en geniş noktasına göre derinliği (43-95)
#     * price: Elmasın dolar bazında fiyatı (326-18.823)
#     * x: Milimetrik cinsten uzunluğu (0-10.74)
#     * y: Milimetrik cinsten genişliği (0-58.90)
#     * z: Milimetrik cinsten derinliği (0-31.80)

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
diamonds = sns.load_dataset("diamonds")
df = diamonds.copy()

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ###### dataseti hakkında bilgi alma

# %%
df.describe().T
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  53940.0     0.797940     0.474011    0.2    0.40     0.70     1.04
# depth  53940.0    61.749405     1.432621   43.0   61.00    61.80    62.50
# table  53940.0    57.457184     2.234491   43.0   56.00    57.00    59.00
# price  53940.0  3932.799722  3989.439738  326.0  950.00  2401.00  5324.25
# x      53940.0     5.731157     1.121761    0.0    4.71     5.70     6.54
# y      53940.0     5.734526     1.142135    0.0    4.72     5.71     6.54
# z      53940.0     3.538734     0.705699    0.0    2.91     3.53     4.04
#
#             max
# carat      5.01
# depth     79.00
# table     95.00
# price  18823.00
# x         10.74
# y         58.90
# z         31.80

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.size
# Out:
# 539400

# %%
df.index
# Out:
# RangeIndex(start=0, stop=53940, step=1)

# %%
df.values
# Out:
# array([[0.23, 'Ideal', 'E', ..., 3.95, 3.98, 2.43],
#        [0.21, 'Premium', 'E', ..., 3.89, 3.84, 2.31],
#        [0.23, 'Good', 'E', ..., 4.05, 4.07, 2.31],
#        ...,
#        [0.7, 'Very Good', 'D', ..., 5.66, 5.68, 3.56],
#        [0.86, 'Premium', 'H', ..., 6.15, 6.12, 3.74],
#        [0.75, 'Ideal', 'D', ..., 5.83, 5.87, 3.64]], dtype=object)

# %%
df.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %% [markdown]
# ###### kategorik değişkenlerde tablo yapmak

# %%
df["cut"].value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
df["color"].value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
df["clarity"].value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.cut.values
# Out:
# ['Ideal', 'Premium', 'Good', 'Premium', 'Good', ..., 'Ideal', 'Good', 'Very Good', 'Premium', 'Ideal']
# Length: 53940
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
df.cut.value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
df["color"].value_counts()
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
df["cut"].loc[1:5]
# Out:
# 1      Premium
# 2         Good
# 3      Premium
# 4         Good
# 5    Very Good
# Name: cut, dtype: category
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
df["cut"].iloc[1:5]
# Out:
# 1    Premium
# 2       Good
# 3    Premium
# 4       Good
# Name: cut, dtype: category
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
df["cut"].value_counts().plot.barh().set_title("Veri Setindeki Cut Değer Sayıları")
# Out:
# Text(0.5, 1.0, 'Veri Setindeki Cut Değer Sayıları')

# %%
df.color.value_counts().plot.barh().set_title("Veri Setindeki Color(Renk) Değer Sayıları")
# Out:
# Text(0.5, 1.0, 'Veri Setindeki Color(Renk) Değer Sayıları')

# %% [markdown]
# df.clarity.value_counts().plot.barh().set_title("Veri Setindeki Clarity Değer Sayıları")

# %% [markdown]
# ###### ordinal tanımlama, istenilen sıralamayı yapma

# %%
from pandas.api.types import CategoricalDtype  #bu kütüphaneyi import etmemiz lazım

# %%
df.cut.astype(CategoricalDtype(ordered = True))
# Out:
# 0            Ideal
# 1          Premium
# 2             Good
# 3          Premium
# 4             Good
#            ...
# 53935        Ideal
# 53936         Good
# 53937    Very Good
# 53938      Premium
# 53939        Ideal
# Name: cut, Length: 53940, dtype: category
# Categories (5, object): ['Ideal' < 'Premium' < 'Very Good' < 'Good' < 'Fair']

# %%
# görüldüğü üzere yukarıda Ideal < Premium gibi yanlış bir sıralama var

# %%
cut_kategoriler = ["Fair", "Good", "Very Good", "Premium", "Ideal"]

# %%
df.cut.head()
# Out:
# 0      Ideal
# 1    Premium
# 2       Good
# 3    Premium
# 4       Good
# Name: cut, dtype: category
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
df.cut = df.cut.astype(CategoricalDtype(categories = cut_kategoriler, ordered = True))

# %%
df.cut.head()
# Out:
# 0      Ideal
# 1    Premium
# 2       Good
# 3    Premium
# 4       Good
# Name: cut, dtype: category
# Categories (5, object): ['Fair' < 'Good' < 'Very Good' < 'Premium' < 'Ideal']

# %%
#görüldüğü üzere değişmiş oldu 
df.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
df.color.head(1)
# Out:
# 0    E
# Name: color, dtype: category
# Categories (7, object): ['D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
df.clarity.head(1)
# Out:
# 0    SI2
# Name: clarity, dtype: category
# Categories (8, object): ['IF', 'VVS1', 'VVS2', 'VS1', 'VS2', 'SI1', 'SI2', 'I1']

# %% [markdown]
# # Barplot

# %%
df["cut"].value_counts().plot.barh().set_title("Cut Değişkenlerinin Sınıf Frekansları")
# Out:
# Text(0.5, 1.0, 'Cut Değişkenlerinin Sınıf Frekansları')

# %%
df.clarity.value_counts().plot.barh().set_title("Clarity Değişkenlerinin Sınıf Frekansları")
# Out:
# Text(0.5, 1.0, 'Clarity Değişkenlerinin Sınıf Frekansları')

# %%
df.color.value_counts().plot.barh().set_title("Color Değişkenlerinin Sınıf Frekansları")
# Out:
# Text(0.5, 1.0, 'Color Değişkenlerinin Sınıf Frekansları')

# %%
sns.barplot(x = "cut", y = df.cut.index, data = df)
# Out:
# <AxesSubplot:xlabel='cut'>

# %%
sns.barplot(x = df.cut.index, y = "cut", data = df)
# Out:
# <AxesSubplot:ylabel='cut'>

# %%
sns.barplot(
    x="cut", 
    y=df.cut.index, 
    data=df, 
    estimator=sum, 
    ci=None, 
    color='#69b3a2'
);

# %%
sns.barplot(
    x=df.cut.index, 
    y="cut", 
    data=df, 
    estimator=sum, 
    ci=None, 
    color='#69b3a2'
);

# %%
sns.barplot(x = "clarity", y = df.clarity.index, data = df)
# Out:
# <AxesSubplot:xlabel='clarity'>

# %%
sns.barplot(x = df.clarity.index, y = "clarity", data = df)
# Out:
# <AxesSubplot:ylabel='clarity'>

# %%
sns.barplot(
    x="clarity", 
    y=df.clarity.index, 
    data=df, 
    estimator=sum, 
    ci=None, 
    color='#65d3f2'
);

# %%
sns.barplot(
    x=df.clarity.index, 
    y="clarity", 
    data=df, 
    estimator=sum, 
    ci=None, 
    color='#65d3f2'
);

# %%
sns.barplot(x = "color", y = df.color.index, data = df)
# Out:
# <AxesSubplot:xlabel='color'>

# %%
sns.barplot(x = df.color.index, y = "color", data = df)
# Out:
# <AxesSubplot:ylabel='color'>

# %%
sns.barplot(
    x=df.clarity.index, 
    y="clarity", 
    data=df, 
    estimator=sum, 
    ci=None, 
    color='#34a7f2'
);

# %%
sns.barplot(
    x="clarity", 
    y=df.clarity.index, 
    data=df, 
    estimator=sum, 
    ci=None, 
    color='#34a7f2'
);

# %% [markdown]
# # Barplot Çaprazlama

# %%
sns.barplot(x = "cut", y = "price", hue = "color", data = df)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
sns.barplot(x = "color", y = "price", hue = "cut", data = df)
# Out:
# <AxesSubplot:xlabel='color', ylabel='price'>

# %%
sns.barplot(x = "cut", y = "price", hue = "clarity", data = df)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
sns.barplot(x = "clarity", y = "price", hue = "color", data = df)
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='price'>

# %% [markdown]
# # Sütun Grafik Çaprazlama

# %%
sns.catplot(x = "cut", y = "price", data = df)

# %%
sns.catplot(x = "clarity", y = "price", data = df)

# %%
sns.catplot(x = "price", y = "cut", data = df)

# %%
sns.catplot(x = "price", y = "color", data = df)

# %%
sns.catplot(x = "cut", y = "price", hue = "color", kind = "point", data = df)

# %% [markdown]
# ###### groupby

# %%
df.groupby(["cut"])["price"].mean()
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Very Good    3981.759891
# Premium      4584.257704
# Ideal        3457.541970
# Name: price, dtype: float64

# %%
df.groupby(["cut", "color"])["price"].mean()
# Out:
# cut        color
# Fair       D        4291.061350
#            E        3682.312500
#            F        3827.003205
#            G        4239.254777
#            H        5135.683168
#            I        4685.445714
#            J        4975.655462
# Good       D        3405.382175
#            E        3423.644159
#            F        3495.750275
#            G        4123.482204
#            H        4276.254986
#            I        5078.532567
#            J        4574.172638
# Very Good  D        3470.467284
#            E        3214.652083
#            F        3778.820240
#            G        3872.753806
#            H        4535.390351
#            I        5255.879568
#            J        5103.513274
# Premium    D        3631.292576
#            E        3538.914420
#            F        4324.890176
#            G        4500.742134
#            H        5216.706780
#            I        5946.180672
#            J        6294.591584
# ...

# %%
df.groupby(["clarity"])["price"].mean()
# Out:
# clarity
# IF      2864.839106
# VVS1    2523.114637
# VVS2    3283.737071
# VS1     3839.455391
# VS2     3924.989395
# SI1     3996.001148
# SI2     5063.028606
# I1      3924.168691
# Name: price, dtype: float64

# %%
df.groupby(["cut", "color"])["price"].std()
# Out:
# cut        color
# Fair       D        3286.114238
#            E        2976.651645
#            F        3223.302685
#            G        3609.644379
#            H        3886.481847
#            I        3730.271132
#            J        4050.458933
# Good       D        3175.148710
#            E        3330.702061
#            F        3202.411187
#            G        3702.504718
#            H        4020.660488
#            I        4631.702141
#            J        3707.790845
# Very Good  D        3523.753268
#            E        3408.023634
#            F        3786.124033
#            G        3861.375464
#            H        4185.798202
#            I        4687.104775
#            J        4135.652742
# Premium    D        3711.634010
#            E        3794.987184
#            F        4012.022756
#            G        4356.571034
#            H        4466.189717
#            I        5053.746146
#            J        4788.936691
# ...

# %% [markdown]
# # Histogram ve Yoğunluk

# %%
sns.displot(df.price, kde = False)

# %%
sns.displot(df.price, bins = 1000, kde = False)

# %%
sns.displot(df.price, bins = 10, kde = False)

# %%
sns.distplot(df.price)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.distplot(df.price, hist = False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.kdeplot(df.price, shade = True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.displot(df.depth, kde = False)

# %%
sns.displot(data = df, x = "price", kind = "ecdf")

# %% [markdown]
# # Çaprazlamalar (FacetGrid)

# %%
(sns.FacetGrid(df,
             hue = "cut",
             height = 5, 
             xlim = (0, 10000))
.map(sns.kdeplot, "price", shade = True)
.add_legend());

# %% [markdown]
# # Violin Grafik

# %%
sns.catplot(y = "price", kind = "violin", data = df)

# %%
sns.catplot(x = "cut", y = "price", kind = "violin", data = df)

# %%
sns.catplot(x = "color", y = "price", kind = "violin", data = df)

# %%
sns.catplot(x = "clarity", y = "price", kind = "violin", data = df)

# %%
sns.catplot(x = "cut", y = "price", hue = "color", kind = "violin", data = df)

# %%
sns.catplot( y = "carat", kind = "violin", data = df)

# %% [markdown]
# # ScatterPlot

# %%
sns.scatterplot(x = "cut", y = "price", data = df)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
sns.scatterplot(x = "color", y = "price", data = df)
# Out:
# <AxesSubplot:xlabel='color', ylabel='price'>

# %%
sns.scatterplot(x = "clarity", y = "price", data = df)
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='price'>

# %%
sns.scatterplot(x = "price", y = "cut", hue = "clarity", data = df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='cut'>

# %% [markdown]
# # Matris Grafikler

# %%
sns.pairplot(data = df)

# %% [markdown]
# # Isı Haritası

# %%
df.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
df_num = df.select_dtypes(include = ["float64", "int64"])  #ısı haritası için sayılardan oluşan tablo lazım
df_num.head()
# Out:
#    carat  depth  table  price     x     y     z
# 0   0.23   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.heatmap(data = df_num)
# Out:
# <AxesSubplot:>
