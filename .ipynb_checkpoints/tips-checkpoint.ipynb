# %% [markdown]
# # Seaborn 'tips' dataseti üzerinde çalışma

# %% [markdown]
# * **tips** <br>
#  _Bir restorandaki ödenen toplam para ile ilişkilendirilen değerlerin tutulduğu veri setidir_
#     * total_bill: Hesabın tutarı (dolar) (3.07-50.81)
#     * tip: Bırakılan bahşiş tutarı (dolar) (1-10)
#     * sex: Hesabı ödeyen kişinin cinsiyeti (Male, Female)
#     * smoker: Masada sigara içildi mi (Yes, No)
#     * day: Haftanın hangi günü (Thur, Fri, Sat, Sun)
#     * time: Günün hangi dilimi (Lunch, Dinner)
#     * size: Masaya oturan kişi sayısı

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset("tips")
df = tips.copy()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Veri seti üzerinden bilgi edinme

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df.info
# Out:
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.shape
# Out:
# (244, 7)

# %%
df.size
# Out:
# 1708

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.values
# Out:
# array([[16.99, 1.01, 'Female', ..., 'Sun', 'Dinner', 2],
#        [10.34, 1.66, 'Male', ..., 'Sun', 'Dinner', 3],
#        [21.01, 3.5, 'Male', ..., 'Sun', 'Dinner', 3],
#        ...,
#        [22.67, 2.0, 'Male', ..., 'Sat', 'Dinner', 2],
#        [17.82, 1.75, 'Male', ..., 'Sat', 'Dinner', 2],
#        [18.78, 3.0, 'Female', ..., 'Thur', 'Dinner', 2]], dtype=object)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# # Kategorik Değişkenlerle Tablo Yapmak

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df["sex"].value_counts().mean()
# Out:
# 122.0

# %%
df["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df.sex.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.smoker.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.day.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.time.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.smoker.values
# Out:
# ['No', 'No', 'No', 'No', 'No', ..., 'No', 'Yes', 'Yes', 'No', 'No']
# Length: 244
# Categories (2, object): ['Yes', 'No']

# %%
df.smoker.value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df["day"].iloc[1:5]
# Out:
# 1    Sun
# 2    Sun
# 3    Sun
# 4    Sun
# Name: day, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
df["day"].loc[1:5]
# Out:
# 1    Sun
# 2    Sun
# 3    Sun
# 4    Sun
# 5    Sun
# Name: day, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
df.day.value_counts().plot.barh().set_title("Günlere Göre Dağılım")
# Out:
# Text(0.5, 1.0, 'Günlere Göre Dağılım')

# %%
df.time.value_counts().plot.barh().set_title("Zaman Göre Dağılım")
# Out:
# Text(0.5, 1.0, 'Zaman Göre Dağılım')

# %%
df.smoker.value_counts().plot.barh().set_title("Sigara İçenlere Göre Dağılım")
# Out:
# Text(0.5, 1.0, 'Sigara İçenlere Göre Dağılım')

# %% [markdown]
# # Barplot

# %%
sns.barplot(x = "sex", y = "total_bill", data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x = "total_bill", y = "smoker", data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='smoker'>

# %%
sns.barplot(
    x="day", 
    y=df.day.index, 
    data=df, 
    estimator=sum, 
    ci=None, 
    color='#12c6a8'
);

# %%
sns.barplot(
    x=df.time.index, 
    y="time", 
    data=df, 
    estimator=sum, 
    ci=None, 
    color='#4123c2'
);

# %% [markdown]
# # Barplot Çaprazlama

# %%
sns.barplot(x = "day", y = "total_bill", hue = "time", data = df)  #görüldüğü üzere haftasonu sabah yemek yenmemiş
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x = "day", y = "total_bill", hue = "smoker", data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x = "day", y = "total_bill", hue = "sex", data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Sütun Grafik Çaprazlama

# %%
sns.catplot(x = "sex", y = "total_bill", data = df)

# %%
sns.catplot(x = "day", y = "total_bill", data = df)

# %%
sns.catplot(x = "total_bill", y = "time", data = df)

# %%
sns.catplot(x = "day", y = "total_bill", hue = "sex", kind  = "point", data = df)

# %% [markdown]
# ### groupby

# %%
df.groupby(["sex"]).sum()
# Out:
#         total_bill     tip  size
# sex
# Male       3256.82  485.07   413
# Female     1570.95  246.51   214

# %%
df.groupby(["smoker"]).sum()
# Out:
#         total_bill     tip  size
# smoker
# Yes        1930.34  279.81   224
# No         2897.43  451.77   403

# %%
df.groupby(["smoker", "sex"]).sum()
# Out:
#                total_bill     tip  size
# smoker sex
# Yes    Male       1337.07  183.07   150
#        Female      593.27   96.74    74
# No     Male       1919.75  302.00   263
#        Female      977.68  149.77   140

# %%
df.groupby(["smoker", "sex"]).mean()
# Out:
#                total_bill       tip      size
# smoker sex
# Yes    Male     22.284500  3.051167  2.500000
#        Female   17.977879  2.931515  2.242424
# No     Male     19.791237  3.113402  2.711340
#        Female   18.105185  2.773519  2.592593

# %%
df.groupby(["smoker", "day"]).mean()
# Out:
#              total_bill       tip      size
# smoker day
# Yes    Thur   19.190588  3.030000  2.352941
#        Fri    16.813333  2.714000  2.066667
#        Sat    21.276667  2.875476  2.476190
#        Sun    24.120000  3.516842  2.578947
# No     Thur   17.113111  2.673778  2.488889
#        Fri    18.420000  2.812500  2.250000
#        Sat    19.661778  3.102889  2.555556
#        Sun    20.506667  3.167895  2.929825

# %% [markdown]
# # Hİstogram ve Yoğunluk Grafiği

# %%
sns.displot(df.total_bill, kde = False)

# %%
sns.displot(df.total_bill, bins = 50, kde = False)

# %%
sns.displot(df.total_bill, bins = 10, kde = False)

# %%
sns.distplot(df.total_bill)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(df.total_bill, hist = False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(df.total_bill, shade = True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(data = df, x = "total_bill", kind = "ecdf")

# %%
sns.barplot(x = "day", y = "tip", hue = "smoker", palette = "ch:.25", data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(df.total_bill)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.boxplot(x = df.total_bill)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# # Sorular

# %%
#Hangi Günler Daha Fazla Kazanıyoruz
sns.boxplot(x = "day", y = "total_bill", data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#Sabah mı akşam mı daha fazla kazanıyoruz
sns.boxplot(x = "time", y = "total_bill", data = df)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
#Kişi Sayısı - Fatura İlişkisi
sns.boxplot(x = "size", y = "total_bill", data = df)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
#Günlere Göre ve O Gündeki Cinsiyetlere Göre Toplam Fatura
sns.boxplot(x = "day", y = "total_bill", hue = "sex", data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#Günlere ve O Gündeki Sigara İçenlere Göre Toplam Fatura
sns.boxplot(x = "day", y = "total_bill", hue = "smoker", data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Violin Grafik

# %%
sns.catplot(y = "total_bill", kind = "violin", data = df)

# %%
sns.catplot(x = "day", y = "total_bill", kind = "violin", data = df)

# %%
sns.catplot(x = "day", y = "total_bill", hue = "sex", kind = "violin", data = df)

# %%
sns.catplot(x = "day", y = "total_bill", hue = "smoker", kind = "violin", data = df)

# %% [markdown]
# # Relplot

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", data = df)

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", style = "time", height = 6, data = tips)

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "size", height = 7, data = df)

# %%
sns.relplot(x = "total_bill", y = "tip", size = "size", sizes = (20, 100), hue = "size", data = df)

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", col = "time", data = df)

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", col = "sex", data = df)

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", col = "day", data = df)

# %% [markdown]
# # Scatterplot

# %%
sns.scatterplot(x = "total_bill", y = "tip", data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = "total_bill", y = "tip", hue = "time", data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = "total_bill", y = "tip", hue = "time", style = "time", data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = "total_bill", y = "tip", hue = "size", size = "size", data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = "total_bill", y = "tip", hue = "smoker", style = "smoker", data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Swarmplot

# %%
sns.swarmplot(x = "day", y = "total_bill", data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x = "day", y = "total_bill", hue = "sex", alpha = .75, data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x = "size", y = "total_bill", data = df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 26.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.swarmplot(x = "size", y = "total_bill", hue = "sex", alpha = .7, data = df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 26.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.swarmplot(x = "day", y = "total_bill", hue = "time", alpha = .5, data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Boxenplot

# %%
sns.boxenplot(x = "sex", y = "tip", hue = "smoker", data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %% [markdown]
# # Violinplot

# %%
sns.violinplot(x = "day", y = "total_bill", hue = "time", data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x = "day", y = "total_bill", hue = "time", bw = .15, data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x = "day", y = "total_bill", hue = "smoker", bw = .25, split = True, data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x = "day", y = "total_bill", hue = "smoker", bw = .25, split = True, palette = "pastel", inner = "stick", 
               data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x = "day", y = "total_bill", hue = "sex", bw = .25, split = True, palette = "pastel", inner = "stick", data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x = "day", y = "total_bill", inner = None, data = df)
sns.swarmplot(x = "day", y = "total_bill", color = "k", size = 3, data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Countplot

# %%
sns.countplot(x = "sex", hue = "smoker", palette = "ch:.25", data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x = "day", hue = "size", palette = "ch:.25", data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %% [markdown]
# # Countplot

# %%
sns.pointplot(x = "day", y = "tip", data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.pointplot(x = "day", y = "size", hue = "sex", linestyles = ["-", "--"], data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='size'>

# %% [markdown]
# # Doğrusal İlişkinin Gösterilmesi

# %%
sns.lmplot(x = "total_bill", y = "tip", data = df)

# %%
sns.lmplot(x = "total_bill", y = "tip", hue = "smoker", data = df)

# %%
sns.lmplot(x = "total_bill", y = "tip", hue = "sex", data = df)

# %%
sns.lmplot(x = "total_bill", y = "tip", hue = "time", data = df)

# %%
sns.lmplot(x = "tip", y = "total_bill", hue = "time", data = df)

# %%
sns.lmplot(x = "total_bill", y = "tip", hue = "smoker",palette = "Set1", data = tips)

# %%
sns.lmplot(x = "total_bill", y = "tip", hue = "smoker",palette = dict(Yes = "g", No = "m"), data = tips)

# %%
sns.lmplot(x = "size", y = "total_bill", hue = "day", col = "day", data = df, height = 6, aspect = .4, x_jitter = .1)

# %%
sns.lmplot(x = "total_bill", y = "tip", hue = "smoker", col = "time", data = df)

# %%
sns.lmplot(x = "total_bill", y = "tip", hue = "sex", col = "smoker", data = df)

# %%
sns.lmplot(x = "total_bill", y = "tip", hue = "smoker", col = "time", row = "sex", data = df)

# %%
sns.lmplot(x = "total_bill", y = "tip", hue = "sex", col = "smoker", row = "time", data = df)

# %% [markdown]
# # Matris Grafik

# %%
sns.pairplot(data = df)

# %%
sns.pairplot(data = df, hue = "sex")

# %%
sns.pairplot(data = df, hue = "smoker")

# %%
sns.pairplot(data = df, hue = "time")

# %% [markdown]
# # Heatmap (Isı Haritası)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df_num = df.select_dtypes(include = ["float64", "int64"])

# %%
sns.heatmap(df_num)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Çizgi Grafik

# %%
sns.lmplot(x = "total_bill", y = "tip", data = df)
