# %% [markdown]
# # Seaborn 'flights' data seti üzerinde çalışma

# %% [markdown]
# * **flights** <br>
# _Yıl ve aylara göre yapılan uçak kazalarında ölen insanların sayısını tutan veri setidir._
#     * year: Kazanın yapıldığı yıl (1949- 1960)
#     * month: Kazanın yapıldığı ay
#     * passengers: Yolcu sayısı (104-622)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
flights = sns.load_dataset("flights")
df = flights.copy()

# %%
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# # Veri seti üzerinden bilgi edinme

# %%
df.describe().T
# Out:
#             count         mean         std     min      25%     50%      75%  \
# year        144.0  1954.500000    3.464102  1949.0  1951.75  1954.5  1957.25
# passengers  144.0   280.298611  119.966317   104.0   180.00   265.5   360.50
#
#                max
# year        1960.0
# passengers   622.0

# %%
df.info
# Out:
# <bound method DataFrame.info of      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]>

# %%
df.dtypes
# Out:
# year             int64
# month         category
# passengers       int64
# dtype: object

# %%
df.shape
# Out:
# (144, 3)

# %%
df.size
# Out:
# 432

# %%
df.index
# Out:
# RangeIndex(start=0, stop=144, step=1)

# %%
df.values
# Out:
# array([[1949, 'Jan', 112],
#        [1949, 'Feb', 118],
#        [1949, 'Mar', 132],
#        [1949, 'Apr', 129],
#        [1949, 'May', 121],
#        [1949, 'Jun', 135],
#        [1949, 'Jul', 148],
#        [1949, 'Aug', 148],
#        [1949, 'Sep', 136],
#        [1949, 'Oct', 119],
#        [1949, 'Nov', 104],
#        [1949, 'Dec', 118],
#        [1950, 'Jan', 115],
#        [1950, 'Feb', 126],
#        [1950, 'Mar', 141],
#        [1950, 'Apr', 135],
#        [1950, 'May', 125],
#        [1950, 'Jun', 149],
#        [1950, 'Jul', 170],
#        [1950, 'Aug', 170],
#        [1950, 'Sep', 158],
#        [1950, 'Oct', 133],
#        [1950, 'Nov', 114],
#        [1950, 'Dec', 140],
#        [1951, 'Jan', 145],
#        [1951, 'Feb', 150],
#        [1951, 'Mar', 178],
#        [1951, 'Apr', 163],
#        [1951, 'May', 172],
#        [1951, 'Jun', 178],
#        [1951, 'Jul', 199],
#        [1951, 'Aug', 199],
#        [1951, 'Sep', 184],
#        [1951, 'Oct', 162],
# ...

# %%
df.columns
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')

# %% [markdown]
# # Kategorik değişkenlerle tablo yapmak

# %%
df.dtypes
# Out:
# year             int64
# month         category
# passengers       int64
# dtype: object

# %%
df.month.values
# Out:
# ['Jan', 'Feb', 'Mar', 'Apr', 'May', ..., 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
# Length: 144
# Categories (12, object): ['Jan', 'Feb', 'Mar', 'Apr', ..., 'Sep', 'Oct', 'Nov', 'Dec']

# %%
df.month.value_counts()
# Out:
# Jan    12
# Feb    12
# Mar    12
# Apr    12
# May    12
# Jun    12
# Jul    12
# Aug    12
# Sep    12
# Oct    12
# Nov    12
# Dec    12
# Name: month, dtype: int64

# %%
df["month"].value_counts()
# Out:
# Jan    12
# Feb    12
# Mar    12
# Apr    12
# May    12
# Jun    12
# Jul    12
# Aug    12
# Sep    12
# Oct    12
# Nov    12
# Dec    12
# Name: month, dtype: int64

# %%
df.month.value_counts().mean()
# Out:
# 12.0

# %%
df.month.value_counts().std()
# Out:
# 0.0

# %%
df.month.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.month.value_counts().plot.barh().set_title("aylar")
# Out:
# Text(0.5, 1.0, 'aylar')

# %% [markdown]
# # Barplot

# %%
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.barplot(x = "month", y = "year", data = df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
sns.barplot(x = "month", y = "passengers", data = df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='passengers'>

# %%
sns.barplot(x = "month", y = "passengers", hue = "year", data = df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='passengers'>

# %%
sns.barplot(x = "year", y = "passengers", hue = "month", data = df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.barplot(
    x="month", 
    y=df.month.index, 
    data=df, 
    estimator=sum, 
    ci=None, 
    color='#12c6a8'
);

# %%
sns.barplot(
    x=df.month.index, 
    y="month", 
    data=df, 
    estimator=sum, 
    ci=None, 
    color='#4123c2'
);

# %% [markdown]
# # Sütun Grafik Çaprazlama

# %%
sns.catplot(x = "month", y = "passengers", data = df)

# %%
sns.catplot(x = "month", y = "year", data = df)  # yıl yapmak çok da iyi olmadı :D

# %%
sns.catplot(x = "month", y = "passengers", data = df)

# %%
sns.catplot(x = "month", y = "passengers", hue = "year", data = df)  # 12 değer olduğu için tablo sığ

# %%
sns.catplot(x = "month", y = "passengers", hue = "year", kind = "point", data = df)

# %% [markdown]
# # Groupby

# %%
df.groupby(["month"]).sum()
# Out:
#         year  passengers
# month
# Jan    23454        2901
# Feb    23454        2820
# Mar    23454        3242
# Apr    23454        3205
# May    23454        3262
# Jun    23454        3740
# Jul    23454        4216
# Aug    23454        4213
# Sep    23454        3629
# Oct    23454        3199
# Nov    23454        2794
# Dec    23454        3142

# %%
df.groupby(["month"]).mean()
# Out:
#          year  passengers
# month
# Jan    1954.5  241.750000
# Feb    1954.5  235.000000
# Mar    1954.5  270.166667
# Apr    1954.5  267.083333
# May    1954.5  271.833333
# Jun    1954.5  311.666667
# Jul    1954.5  351.333333
# Aug    1954.5  351.083333
# Sep    1954.5  302.416667
# Oct    1954.5  266.583333
# Nov    1954.5  232.833333
# Dec    1954.5  261.833333

# %%
df.groupby(["month"]).std()
# Out:
#            year  passengers
# month
# Jan    3.605551  101.032960
# Feb    3.605551   89.619397
# Mar    3.605551  100.559194
# Apr    3.605551  107.374839
# May    3.605551  114.739890
# Jun    3.605551  134.219856
# Jul    3.605551  156.827255
# Aug    3.605551  155.783333
# Sep    3.605551  123.954140
# Oct    3.605551  110.744964
# Nov    3.605551   95.185783
# Dec    3.605551  103.093808

# %% [markdown]
# # Histogram ve Yoğunluk

# %%
sns.displot(df.month, kde = False)

# %%
sns.displot(df.passengers, kde = False)

# %%
sns.displot(df.year, kde = False)

# %%
sns.displot(df.year)

# %%
sns.displot(df.passengers, bins = 20, kde = False)

# %%
sns.displot(data = df, x = "passengers", kind = "ecdf")

# %%
sns.displot(data = df, x = "year", kind = "ecdf")

# %%
sns.distplot(df.year)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='year', ylabel='Density'>

# %%
sns.distplot(df.passengers)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='passengers', ylabel='Density'>

# %%
sns.distplot(df.passengers, hist = False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='passengers', ylabel='Density'>

# %%
sns.kdeplot(df.passengers, shade = True)
# Out:
# <AxesSubplot:xlabel='passengers', ylabel='Density'>

# %%
sns.displot(data = df, x = "year", y = "passengers")

# %%
sns.displot(data = df, x = "year", y = "passengers", kind = "kde")

# %%
sns.displot(data = df, x = "year", y = "passengers", kind = "kde", rug = True)

# %%
sns.displot(data = df, x = "passengers", hue = "year", multiple = "stack")

# %%
sns.displot(data = df, x = "passengers", hue = "year", kind = "kde")

# %%
sns.displot(data = df, y = "passengers", hue = "year", kind = "ecdf", height = 4, aspect = .7)

# %%
g = sns.displot(data = df, y = "passengers", hue = "year", kind = "kde", height = 4, aspect = .7)
g.set_axis_labels("Passengers", "Proportion")
g.set_titles("Flight")

# %%
sns.displot(x = "year", y = "passengers", bins = int(len(df.year) / len(df.groupby(["month"]))), data = df)  #yıl sayısı kadar

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x = df.passengers)
# Out:
# <AxesSubplot:xlabel='passengers'>

# %%
sns.boxplot(x = df.year)
# Out:
# <AxesSubplot:xlabel='year'>
