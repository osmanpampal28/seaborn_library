# %% [markdown]
# # Seaborn 'iris' dataseti üzerinde çalışma

# %% [markdown]
# * **iris** <br>
# _Belirli bir cinse ait çiçek türlerini birbirinden ayırmak için yaprak uzunlukları ve genişlikleri kullanılır. Türlere göre bu özellikleri tutan veri setidir._
#     * sepal_length: Cm cinsinden çanak yaprağın uzunluğu (4.3-7.9)
#     * sepal_width: Cm cinsinden çanak yaprağın genişliği (2.0-4.4)
#     * petal_length: Cm cinsinden taç yaprak uzunluğu (1.0-6.9)
#     * petal_width: Cm cinsinden taç yaprak genişliği (0.1-2.5)
#     * species: Bitkinin türü

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
iris = sns.load_dataset("iris")
df = iris.copy()

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Veri seti üzerinden bilgi edinme

# %%
df.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %%
df.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.shape
# Out:
# (150, 5)

# %%
df.size
# Out:
# 750

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.values
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'setosa'],
#        [5.1, 3.3, 1.7, 0.5, 'setosa'],
# ...

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# # Kategorik Değişkenlerle Tablo Yapmak

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df["species"].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
df.species.value_counts().mean()
# Out:
# 50.0

# %%
df.species.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.species.value_counts().plot.barh().set_title("Bitki Türleri")
# Out:
# Text(0.5, 1.0, 'Bitki Türleri')

# %%
df.species.value_counts().plot.barh().set_title("Türler")
# Out:
# Text(0.5, 1.0, 'Türler')

# %% [markdown]
# # Barplot

# %%
sns.barplot(x = "species", y = "petal_width", data = df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
sns.barplot(x = "species", y = "petal_length", data = df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.barplot(x = "species", y = "sepal_length", data = df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.barplot(x = "species", y = "sepal_width", data = df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
sns.barplot(x = "species", y = "sepal_width", hue = "sepal_length", data = df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
sns.barplot(x = "species", y = "petal_width", hue = "petal_length", data = df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
sns.barplot(x = "species", y = "sepal_length", hue = "sepal_width", data = df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.barplot(x = "species", y = "petal_length", hue = "petal_width", data = df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %% [markdown]
# # Sütun Grafik Çaprazlama

# %%
sns.catplot(x = "species", y = "sepal_width", data = df)

# %%
sns.catplot(x = "species", y = "petal_width", data = df)

# %%
sns.catplot(x = "species", y = "petal_length", data = df)

# %%
sns.catplot(x = "species", y = "sepal_length", data = df)

# %%
sns.catplot(x = "sepal_length", y = "species", data = df)

# %%
sns.catplot(x = "species", y = "sepal_width", hue = "sepal_length", kind = "point", data = df)

# %%
sns.catplot(x = "species", y = "petal_width", hue = "petal_length", kind = "point", data = df)

# %% [markdown]
# # Groupby

# %%
df.groupby(["species"]).sum()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             250.3        171.4          73.1         12.3
# versicolor         296.8        138.5         213.0         66.3
# virginica          329.4        148.7         277.6        101.3

# %%
df.groupby(["species"]).mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
df.groupby(["species"]).std()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa          0.352490     0.379064      0.173664     0.105386
# versicolor      0.516171     0.313798      0.469911     0.197753
# virginica       0.635880     0.322497      0.551895     0.274650

# %% [markdown]
# # Histogram ve Yoğunluk

# %%
sns.displot(df.sepal_width, kde = False)

# %%
sns.displot(df.sepal_length, kde = False)

# %%
sns.displot(df.petal_width, kde = False)

# %%
sns.displot(df.petal_length, kde = False)

# %%
sns.displot(df.petal_length, bins = 20, kde = False)

# %%
sns.displot(data = df, x = "petal_length", kind = "ecdf")

# %%
sns.displot(data = df, x = "petal_width", kind = "ecdf")

# %%
sns.displot(data = df, x = "sepal_length", kind = "ecdf")

# %%
sns.displot(data = df, x = "sepal_width", kind = "ecdf")

# %%
sns.distplot(df.petal_length)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='petal_length', ylabel='Density'>

# %%
sns.distplot(df.petal_length, hist = False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='petal_length', ylabel='Density'>

# %%
sns.kdeplot(df.petal_length, shade = True)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Density'>

# %%
sns.displot(data = df, x = "petal_length", y = "petal_width")

# %%
sns.displot(data = df, x = "sepal_length", y = "sepal_width")

# %%
sns.displot(data = df, x = "petal_length", y = "sepal_width", kind = "kde")

# %%
sns.displot(data = df, x = "petal_length", y = "sepal_width", kind = "kde", rug = True)

# %%
sns.displot(data = df, x = "sepal_length", y = "sepal_width", kind = "kde")

# %%
sns.displot(data = df, x = "sepal_length", y = "sepal_width", kind = "kde", rug = True)

# %%
sns.displot(data = df, x = "petal_width", hue = "species", multiple = "stack")

# %%
sns.displot(data = df, x = "petal_width", hue = "species", kind = "kde")

# %%
sns.displot(data = df, y = "petal_width", hue = "species", kind = "ecdf", height = 4, aspect = .7)

# %%
g = sns.displot(data = df, y = "petal_length", hue = "species", kind = "kde", height = 4, aspect = .7)
g.set_axis_labels("Proportion", "Petal Width")
g.set_titles("İris")

# %%
g = sns.displot(data = df, x = "petal_length", hue = "species", kind = "kde", height = 4, aspect = .7)
g.set_axis_labels("Petal Width", "Proportion")
g.set_titles("İris")

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x = df["sepal_width"])
# Out:
# <AxesSubplot:xlabel='sepal_width'>

# %%
sns.boxplot(x = df["petal_width"])
# Out:
# <AxesSubplot:xlabel='petal_width'>

# %%
sns.boxplot(x = df["sepal_length"])
# Out:
# <AxesSubplot:xlabel='sepal_length'>

# %%
sns.boxplot(x = df["petal_length"])
# Out:
# <AxesSubplot:xlabel='petal_length'>

# %%
sns.boxplot(x = "species", y = "sepal_width", data = df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
sns.boxplot(x = "species", y = "sepal_length", data = df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.boxplot(x = "species", y = "petal_width", data = df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
sns.boxplot(x = "species", y = "petal_length", data = df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %% [markdown]
# # Violin Grafik

# %%
sns.catplot(y = "sepal_width", kind = "violin", data = df)

# %%
sns.catplot(y = "sepal_length", kind = "violin", data = df)

# %%
sns.catplot(y = "petal_width", kind = "violin", data = df)

# %%
sns.catplot(y = "petal_length", kind = "violin", data = df)

# %%
sns.catplot(x = "species", y = "sepal_width",kind = "violin", data = df)

# %% [markdown]
# # Relplot

# %%
sns.relplot(x = "sepal_width", y = "sepal_length", hue = "species", data = df)

# %%
sns.relplot(x = "petal_width", y = "petal_length", hue = "species", data = df)

# %% [markdown]
# # Scatterplot

# %%
sns.scatterplot(x = "petal_width", y = "petal_length", data = df)
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>

# %%
sns.scatterplot(x = "sepal_width", y = "sepal_length", data = df)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>

# %%
sns.scatterplot(x = "petal_width", y = "petal_length", hue = "species", data = df)
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>

# %%
sns.scatterplot(x = "sepal_width", y = "sepal_length", hue = "species", data = df)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>

# %%
sns.scatterplot(x = "sepal_width", y = "sepal_length", hue = "species", size = "sepal_width", data = df)
plt.legend(bbox_to_anchor=(1.01, 1), borderaxespad=0)  #legend yani tabloyu grafik dışında gösterir

# %% [markdown]
# # Swarmplot

# %%
sns.swarmplot(x = "species", y = "sepal_width", data = df)
plt.xlabel("Species")
plt.ylabel("Sepal Width")
# Out:
# Text(0, 0.5, 'Sepal Width')

# %%
sns.swarmplot(x = "species", y = "sepal_length", data = df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# # Boxenplot

# %%
sns.boxenplot(x = "petal_width", y = "petal_length", hue = "species", data = df)
plt.legend(frameon = False)

# %% [markdown]
# # Violinplot

# %%
sns.violinplot(x = "species", y = "petal_length", data = df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>
