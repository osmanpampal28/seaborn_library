# %% [markdown]
# # Seaborn 'mpg' Veri Seti Üzerinde Çalışma

# %% [markdown]
# * **mpg** <br>
# _Arabaların özelliklerine göre sıralandığı veri setidir._
#     * mpg: 1 galon benzin ile katedilen yol (1 galon = 3.7 L, 1 mil = 1.6 Km)(9-46.6)
#     * cylinders: Arabada bulunan silindir sayısı
#     * displacement: Motor hacmi (68-455)
#     * horsepower: Beygir gücü (46-230)
#     * weight: Ağırlık (1613-5140)
#     * acceleration: Saniye cinsinden 0-100 Km/s hıza ulaşma süresi (8-24.8)
#     * model_year: 1900'lü yıllara göre araba modeli yılı (70-82)
#     * origin: Arabanın üretim yılı
#     * name: Arabanın model ismi

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
mpg = sns.load_dataset("mpg")
df = mpg.copy()

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# # Veri seti üzerinden bilgi edinme

# %%
df.describe().T
# Out:
#               count         mean         std     min       25%     50%  \
# mpg           398.0    23.514573    7.815984     9.0    17.500    23.0
# cylinders     398.0     5.454774    1.701004     3.0     4.000     4.0
# displacement  398.0   193.425879  104.269838    68.0   104.250   148.5
# horsepower    392.0   104.469388   38.491160    46.0    75.000    93.5
# weight        398.0  2970.424623  846.841774  1613.0  2223.750  2803.5
# acceleration  398.0    15.568090    2.757689     8.0    13.825    15.5
# model_year    398.0    76.010050    3.697627    70.0    73.000    76.0
#
#                    75%     max
# mpg             29.000    46.6
# cylinders        8.000     8.0
# displacement   262.000   455.0
# horsepower     126.000   230.0
# weight        3608.000  5140.0
# acceleration    17.175    24.8
# model_year      79.000    82.0

# %%
df.info
# Out:
# <bound method DataFrame.info of       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
df.shape
# Out:
# (398, 9)

# %%
df.size
# Out:
# 3582

# %%
df.index
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
df.values
# Out:
# array([[18.0, 8, 307.0, ..., 70, 'usa', 'chevrolet chevelle malibu'],
#        [15.0, 8, 350.0, ..., 70, 'usa', 'buick skylark 320'],
#        [18.0, 8, 318.0, ..., 70, 'usa', 'plymouth satellite'],
#        ...,
#        [32.0, 4, 135.0, ..., 82, 'usa', 'dodge rampage'],
#        [28.0, 4, 120.0, ..., 82, 'usa', 'ford ranger'],
#        [31.0, 4, 119.0, ..., 82, 'usa', 'chevy s-10']], dtype=object)

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
min(df.acceleration)
# Out:
# 8.0

# %%
max(df.acceleration)
# Out:
# 24.8

# %%
min(df.model_year)
# Out:
# 70

# %%
max(df.model_year)
# Out:
# 82

# %%
min(df.horsepower)
# Out:
# 46.0

# %%
max(df.horsepower)
# Out:
# 230.0

# %% [markdown]
# # Kategorik Değişkenlerle Tablo Yapmak

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
df.origin.values
# Out:
# array(['usa', 'usa', 'usa', 'usa', 'usa', 'usa', 'usa', 'usa', 'usa',
#        'usa', 'usa', 'usa', 'usa', 'usa', 'japan', 'usa', 'usa', 'usa',
#        'japan', 'europe', 'europe', 'europe', 'europe', 'europe', 'usa',
#        'usa', 'usa', 'usa', 'usa', 'japan', 'usa', 'japan', 'usa', 'usa',
#        'usa', 'usa', 'usa', 'usa', 'usa', 'usa', 'usa', 'usa', 'usa',
#        'usa', 'usa', 'usa', 'usa', 'usa', 'usa', 'usa', 'europe',
#        'europe', 'europe', 'japan', 'japan', 'europe', 'usa', 'japan',
#        'usa', 'europe', 'usa', 'usa', 'usa', 'usa', 'usa', 'usa', 'usa',
#        'usa', 'usa', 'usa', 'usa', 'japan', 'usa', 'usa', 'usa', 'usa',
#        'europe', 'europe', 'europe', 'europe', 'usa', 'japan', 'japan',
#        'usa', 'japan', 'usa', 'usa', 'usa', 'usa', 'usa', 'usa', 'usa',
#        'usa', 'usa', 'usa', 'usa', 'usa', 'usa', 'usa', 'usa', 'usa',
#        'usa', 'europe', 'usa', 'usa', 'usa', 'usa', 'usa', 'japan', 'usa',
# ...

# %%
df.origin.value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
df.name.values
# Out:
# array(['chevrolet chevelle malibu', 'buick skylark 320',
#        'plymouth satellite', 'amc rebel sst', 'ford torino',
#        'ford galaxie 500', 'chevrolet impala', 'plymouth fury iii',
#        'pontiac catalina', 'amc ambassador dpl', 'dodge challenger se',
#        "plymouth 'cuda 340", 'chevrolet monte carlo',
#        'buick estate wagon (sw)', 'toyota corona mark ii',
#        'plymouth duster', 'amc hornet', 'ford maverick', 'datsun pl510',
#        'volkswagen 1131 deluxe sedan', 'peugeot 504', 'audi 100 ls',
#        'saab 99e', 'bmw 2002', 'amc gremlin', 'ford f250', 'chevy c20',
#        'dodge d200', 'hi 1200d', 'datsun pl510', 'chevrolet vega 2300',
#        'toyota corona', 'ford pinto', 'amc gremlin',
#        'plymouth satellite custom', 'chevrolet chevelle malibu',
#        'ford torino 500', 'amc matador', 'chevrolet impala',
#        'pontiac catalina brougham', 'ford galaxie 500',
#        'plymouth fury iii', 'dodge monaco (sw)',
# ...

# %%
df.name.value_counts()
# Out:
# ford pinto             6
# toyota corolla         5
# amc matador            5
# ford maverick          5
# chevrolet chevette     4
#                       ..
# chevrolet monza 2+2    1
# ford mustang ii        1
# pontiac astro          1
# amc pacer              1
# chevy s-10             1
# Name: name, Length: 305, dtype: int64

# %%
df.origin.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.origin.value_counts().plot.barh().set_title("Arabaların aslen üretildikleri yerler")
# Out:
# Text(0.5, 1.0, 'Arabaların aslen üretildikleri yerler')

# %%
df.origin.loc[2:5]
# Out:
# 2    usa
# 3    usa
# 4    usa
# 5    usa
# Name: origin, dtype: object

# %%
df.name.loc[1:7]
# Out:
# 1     buick skylark 320
# 2    plymouth satellite
# 3         amc rebel sst
# 4           ford torino
# 5      ford galaxie 500
# 6      chevrolet impala
# 7     plymouth fury iii
# Name: name, dtype: object

# %%
df.name.iloc[2:6]
# Out:
# 2    plymouth satellite
# 3         amc rebel sst
# 4           ford torino
# 5      ford galaxie 500
# Name: name, dtype: object

# %%
df.origin.iloc[2:6]
# Out:
# 2    usa
# 3    usa
# 4    usa
# 5    usa
# Name: origin, dtype: object

# %%
len(pd.unique(df["name"]))
# Out:
# 305

# %%
len(df.name)  #görüldüğü üzere araba isimleri genel olarak eşsiz denebilir
# Out:
# 398

# %% [markdown]
# # Barplot

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
sns.barplot(x = "origin", y = "weight", data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='weight'>

# %%
sns.barplot(x = "origin", y = "model_year", data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='model_year'>

# %%
sns.barplot(x = "origin", y = "horsepower", data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='horsepower'>

# %%
sns.barplot(x = "origin", y = "displacement", data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='displacement'>

# %%
sns.barplot(x = "origin", y = "cylinders", data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='cylinders'>

# %%
sns.barplot(x = "origin", y = "mpg", data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.barplot(
    x="origin", 
    y=df.origin.index, 
    data=df, 
    estimator=sum, 
    ci=None, 
    color='#12c6a8'
);

# %%
sns.barplot(
    x=df.origin.index, 
    y="origin", 
    data=df, 
    estimator=sum, 
    ci=None, 
    color='#4123c2'
);

# %% [markdown]
# # Barplot çaprazlama

# %%
sns.barplot(x = "origin", y = "acceleration", data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='acceleration'>

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.barplot(x = "origin", y = "displacement", hue = "model_year", data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='displacement'>

# %%
sns.barplot(x = "origin", y = "acceleration", hue = "model_year", data = df)
plt.legend(bbox_to_anchor=(1.01, 1), borderaxespad=0)

# %%
sns.barplot(x = "origin", y = "mpg", hue = "model_year", data = df)
plt.legend(bbox_to_anchor=(1.01, 1), borderaxespad=0)

# %% [markdown]
# # Sütun Grafik Çaprazlama

# %%
sns.catplot(x = "origin", y = "acceleration", data = df)

# %%
sns.catplot(x = "origin", y = "acceleration", hue = "model_year", data = df)

# %%
sns.catplot(x = "origin", y = "mpg", data = df)

# %%
sns.catplot(x = "origin", y = "mpg", data = df)

# %%
sns.catplot(x = "origin", y = "mpg", hue = "model_year", data = df)

# %%
sns.catplot(x = "origin", y = "horsepower", data = df)

# %%
sns.catplot(x = "origin", y = "horsepower",hue = "model_year", data = df)

# %%
sns.catplot(x = "origin", y = "weight", data = df)

# %%
sns.catplot(x = "origin", y = "weight", hue = "model_year", data = df)

# %%
sns.catplot(x = "origin", y = "mpg", hue = "cylinders", data = df)

# %%
sns.catplot(x = "origin", y = "cylinders", data = df)

# %%
sns.catplot(x = "origin", y = "cylinders", hue = "model_year", data = df)

# %%
sns.catplot(x = "mpg", y = "origin", data = df)

# %%
sns.catplot(x = "origin", y = "mpg", hue = "model_year", kind = "point", data = df)

# %%
sns.catplot(x = "origin", y = "acceleration", hue = "model_year", kind = "point", data = df)

# %%
sns.catplot(x = "origin", y = "horsepower", hue = "model_year", kind = "point", data = df)

# %%
sns.catplot(x = "origin", y = "weight", hue = "model_year", kind = "point", data = df)

# %% [markdown]
# # Groupby

# %%
df.groupby(["origin"]).sum()
# Out:
#            mpg  cylinders  displacement  horsepower  weight  acceleration  \
# origin
# europe  1952.4        291        7640.0      5478.0  169631        1175.1
# japan   2405.6        324        8114.0      6307.0  175477        1277.6
# usa     5000.8       1556       61229.5     29167.0  837121        3743.4
#
#         model_year
# origin
# europe        5307
# japan         6118
# usa          18827

# %%
df.groupby(["origin"]).mean()
# Out:
#               mpg  cylinders  displacement  horsepower       weight  \
# origin
# europe  27.891429   4.157143    109.142857   80.558824  2423.300000
# japan   30.450633   4.101266    102.708861   79.835443  2221.227848
# usa     20.083534   6.248996    245.901606  119.048980  3361.931727
#
#         acceleration  model_year
# origin
# europe     16.787143   75.814286
# japan      16.172152   77.443038
# usa        15.033735   75.610442

# %%
df.groupby(["origin"]).std()
# Out:
#              mpg  cylinders  displacement  horsepower      weight  \
# origin
# europe  6.723930   0.500310     22.582079   20.157871  490.043191
# japan   6.090048   0.590414     23.140126   17.819199  320.497248
# usa     6.402892   1.661425     98.501839   39.897790  794.792506
#
#         acceleration  model_year
# origin
# europe      3.045687    3.469506
# japan       1.954937    3.650595
# usa         2.751112    3.677094

# %%
df.groupby(["origin", "name"]).mean()
# Out:
#                                 mpg  cylinders  displacement  horsepower  \
# origin name
# europe audi 100 ls            24.00        4.0         107.0        90.0
#        audi 100ls             21.50        4.0         114.5        93.0
#        audi 4000              34.30        4.0          97.0        78.0
#        audi 5000              20.30        5.0         131.0       103.0
#        audi 5000s (diesel)    36.40        5.0         121.0        67.0
# ...                             ...        ...           ...         ...
# usa    pontiac phoenix        30.25        4.0         151.0        90.0
#        pontiac phoenix lj     19.20        6.0         231.0       105.0
#        pontiac safari (sw)    13.00        8.0         400.0       175.0
#        pontiac sunbird coupe  24.50        4.0         151.0        88.0
#        pontiac ventura sj     18.50        6.0         250.0       110.0
#
#                               weight  acceleration  model_year
# origin name
# ...

# %%
df.groupby(["name"]).mean()  #name değerinde yaklaşık 300 unique değişken olduğundan çok da verimli sayılmaz
# Out:
#                            mpg  cylinders  displacement  horsepower  weight  \
# name
# amc ambassador brougham  13.00        8.0         360.0       175.0  3821.0
# amc ambassador dpl       15.00        8.0         390.0       190.0  3850.0
# amc ambassador sst       17.00        8.0         304.0       150.0  3672.0
# amc concord              21.85        5.0         191.5        90.0  3106.5
# amc concord d/l          18.10        6.0         258.0       120.0  3410.0
# ...                        ...        ...           ...         ...     ...
# vw dasher (diesel)       43.40        4.0          90.0        48.0  2335.0
# vw pickup                44.00        4.0          97.0        52.0  2130.0
# vw rabbit                35.25        4.0          94.0        73.0  2040.5
# vw rabbit c (diesel)     44.30        4.0          90.0        48.0  2085.0
# vw rabbit custom         31.90        4.0          89.0        71.0  1925.0
#
#                          acceleration  model_year
# ...

# %% [markdown]
# # Histogram ve Yoğunluk

# %%
sns.displot(df.acceleration, kde = False)

# %%
sns.displot(df.weight, kde = False)

# %%
sns.displot(df.horsepower)

# %%
sns.displot(df.mpg, kde = False)

# %%
sns.displot(df.cylinders, bins = 5, kde = False)

# %%
sns.displot(df.model_year,bins = 12, kde = False)

# %%
sns.displot(data = df, x = "mpg", kind = "ecdf")

# %%
sns.displot(data = df, x = "acceleration", kind  = "ecdf")

# %%
sns.displot(data = df, x = "weight", kind = "ecdf")

# %%
sns.displot(data = df, x = "mpg", hue = "cylinders", kind = "kde", palette = "colorblind", aspect = 2)

# %%
sns.distplot(df.mpg)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.distplot(df.mpg, hist = False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.kdeplot(df.mpg, shade = True)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.displot(data = df, x = "mpg", y = "cylinders")

# %%
sns.displot(data = df, x = "mpg", y = "model_year", kind = "kde")

# %%
sns.displot(data = df, x = "mpg", hue = "model_year", multiple = "stack")

# %%
sns.displot(data = df, x = "mpg", hue = "cylinders", kind = "kde")

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x = df.mpg)
# Out:
# <AxesSubplot:xlabel='mpg'>

# %%
sns.boxplot(x = df.cylinders)
# Out:
# <AxesSubplot:xlabel='cylinders'>

# %%
sns.boxplot(x = df.model_year)
# Out:
# <AxesSubplot:xlabel='model_year'>

# %%
sns.boxplot(x = df.horsepower)
# Out:
# <AxesSubplot:xlabel='horsepower'>

# %%
sns.boxplot(x = df.displacement)
# Out:
# <AxesSubplot:xlabel='displacement'>

# %%
sns.boxplot(x = df.acceleration)
# Out:
# <AxesSubplot:xlabel='acceleration'>

# %%
sns.boxplot(x = "origin", y = "mpg", data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x = "origin", y = "mpg", hue = "cylinders", data = df)
plt.legend(bbox_to_anchor=(1.01, 1), borderaxespad=0)

# %%
sns.boxplot(x = "cylinders", y = "mpg", data = df)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='mpg'>

# %% [markdown]
# # Violin Grafik

# %%
sns.catplot(y = "mpg", kind = "violin", data = df)

# %%
sns.catplot(x = "origin", y = "mpg",kind = "violin", data = df)

# %%
sns.catplot(x = "origin", y = "acceleration",kind = "violin", data = df)

# %%
sns.catplot(x = "origin", y = "mpg",hue = "cylinders",kind = "violin", data = df)

# %%
sns.catplot(x = "origin", y = "acceleration",hue = "cylinders",kind = "violin", data = df)

# %%
sns.catplot(x = "cylinders", y = "mpg",hue = "origin",kind = "violin", data = df)

# %% [markdown]
# # Relplot

# %%
sns.relplot(x = "cylinders", y = "acceleration", data = df)

# %%
sns.relplot(x = "cylinders", y = "mpg", data = df)

# %%
sns.relplot(x = "horsepower", y = "mpg", data = df)

# %%
sns.relplot(x = "horsepower", y = "acceleration", data = df)

# %%
sns.relplot(x = "horsepower", y = "acceleration",hue = "origin", data = df)

# %%
sns.relplot(x = "horsepower", y = "mpg",hue = "origin", data = df)

# %%
sns.relplot(x = "mpg", y = "acceleration",hue = "origin", data = df)

# %%
sns.relplot(x = "horsepower", y = "acceleration",hue = "cylinders", data = df)

# %%
sns.relplot(x = "horsepower", y = "acceleration",hue = "origin",size = "cylinders", data = df)

# %%
sns.relplot(x = "horsepower", y = "mpg",hue = "origin",size = "cylinders",height = 7, data = df)

# %%
sns.relplot(x = "weight", y = "mpg",hue = "cylinders",col = "origin", data = df)

# %%
sns.relplot(x = "displacement", y = "mpg",hue = "cylinders",row = "origin", data = df)

# %% [markdown]
# # Scatterplot

# %%
sns.scatterplot(x = "acceleration", y = "model_year", data = df)
# Out:
# <AxesSubplot:xlabel='acceleration', ylabel='model_year'>

# %%
sns.scatterplot(x = "weight", y = "mpg", data = df)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
sns.scatterplot(x = "weight",hue = "origin", y = "mpg", data = df)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
sns.scatterplot(x = "acceleration", y = "mpg", hue = "origin", data = df)
# Out:
# <AxesSubplot:xlabel='acceleration', ylabel='mpg'>

# %%
sns.scatterplot(x = "acceleration", y = "mpg", hue = "cylinders", data = df)
# Out:
# <AxesSubplot:xlabel='acceleration', ylabel='mpg'>

# %%
sns.scatterplot(x = "acceleration", y = "mpg", hue = "cylinders",size = "cylinders", data = df)
# Out:
# <AxesSubplot:xlabel='acceleration', ylabel='mpg'>

# %%
sns.scatterplot(x = "weight", y = "mpg", hue = "origin", style = "cylinders", data = df)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %% [markdown]
# # Swarmplot

# %%
sns.swarmplot(x = "origin", y = "acceleration", data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='acceleration'>

# %%
sns.swarmplot(x = "origin", y = "weight",alpha = .75, data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='weight'>

# %%
sns.swarmplot(x = "origin", y = "horsepower", alpha = .25, data = df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='origin', ylabel='horsepower'>

# %%
sns.swarmplot(x = "origin", y = "acceleration",hue = "cylinders", data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='acceleration'>

# %%
sns.swarmplot(x = "cylinders", y = "mpg", data = df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 23.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='cylinders', ylabel='mpg'>

# %%
sns.swarmplot(x = "origin", y = "acceleration", hue = "cylinders", data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='acceleration'>

# %% [markdown]
# # Boxenplot

# %%
sns.boxenplot(x = "origin", y = "acceleration", data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='acceleration'>

# %%
sns.boxenplot(x = "origin", y = "mpg", hue = "cylinders", data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxenplot(x = "origin", y = "weight", hue = "cylinders", data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='weight'>

# %%
sns.boxenplot(x = "cylinders", y = "horsepower", hue = "origin", data = df)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %% [markdown]
# # Violinplot

# %%
sns.violinplot(x = "origin", y = "mpg", data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.violinplot(x = "origin", y = "weight", hue = "cylinders", data =df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='weight'>

# %%
sns.violinplot(x = "origin", y = "acceleration", hue = "cylinders", bw = .25, data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='acceleration'>

# %%
sns.violinplot(x = "cylinders", y = "horsepower", hue = "origin", palette = "pastel", data = df)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %%
sns.violinplot(x = "origin", y = "mpg", inner = None, data = df)
sns.swarmplot(x = "origin", y = "mpg", color = "yellow", size = 3, data = df)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %% [markdown]
# # Countplot

# %%
sns.countplot(x = "cylinders", hue = "origin", palette = "ch:.25", data = df)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='count'>
